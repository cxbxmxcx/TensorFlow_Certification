# %% [markdown]
# <a href="https://colab.research.google.com/github/cxbxmxcx/TensorFlow_Certification/blob/master/TensorFlow_Seq2Seq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q tensorflow-text
# Out:
#      |████████████████████████████████| 3.0MB 3.5MB/s

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_text as text
import numpy as np
import os

# %%
# Download the file
path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"
path_to_file
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2646016/2638744 [==============================] - 0s 0us/step
# '/root/.keras/datasets/spa-eng/spa.txt'

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 1000  # Number of samples to train on.

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(path_to_file, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

lines[:10]
# Out:
# ['Go.\tVe.',
#  'Go.\tVete.',
#  'Go.\tVaya.',
#  'Go.\tVáyase.',
#  'Hi.\tHola.',
#  'Run!\t¡Corre!',
#  'Run.\tCorred.',
#  'Who?\t¿Quién?',
#  'Fire!\t¡Fuego!',
#  'Fire!\t¡Incendio!']

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 1000
# Number of unique input tokens: 61
# Number of unique output tokens: 70
# Max sequence length for inputs: 11
# Max sequence length for outputs: 31

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np

# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 281ms/step - loss: 2.2204 - accuracy: 0.5765 - val_loss: 2.1606 - val_accuracy: 0.5777
# Epoch 2/100
# 13/13 [==============================] - 3s 203ms/step - loss: 1.6379 - accuracy: 0.6262 - val_loss: 1.7552 - val_accuracy: 0.5711
# Epoch 3/100
# 13/13 [==============================] - 3s 207ms/step - loss: 1.5480 - accuracy: 0.6241 - val_loss: 1.6728 - val_accuracy: 0.5750
# Epoch 4/100
# 13/13 [==============================] - 3s 201ms/step - loss: 1.4877 - accuracy: 0.6282 - val_loss: 1.8844 - val_accuracy: 0.5910
# Epoch 5/100
# 13/13 [==============================] - 3s 204ms/step - loss: 1.4279 - accuracy: 0.6360 - val_loss: 1.5917 - val_accuracy: 0.5826
# Epoch 6/100
# 13/13 [==============================] - 3s 204ms/step - loss: 1.4034 - accuracy: 0.6417 - val_loss: 1.5727 - val_accuracy: 0.5955
# Epoch 7/100
# 13/13 [==============================] - 3s 203ms/step - loss: 1.3556 - accuracy: 0.6467 - val_loss: 1.5816 - val_accuracy: 0.5903
# Epoch 8/100
# 13/13 [==============================] - 3s 206ms/step - loss: 1.3257 - accuracy: 0.6502 - val_loss: 1.7550 - val_accuracy: 0.5966
# Epoch 9/100
# 13/13 [==============================] - 3s 201ms/step - loss: 1.2877 - accuracy: 0.6588 - val_loss: 1.4807 - val_accuracy: 0.6031
# Epoch 10/100
# 13/13 [==============================] - 3s 206ms/step - loss: 1.2448 - accuracy: 0.6706 - val_loss: 1.7326 - val_accuracy: 0.6381
# Epoch 11/100
# 13/13 [==============================] - 3s 199ms/step - loss: 1.2327 - accuracy: 0.6779 - val_loss: 1.3978 - val_accuracy: 0.6173
# Epoch 12/100
# 13/13 [==============================] - 3s 207ms/step - loss: 1.1637 - accuracy: 0.6883 - val_loss: 1.3650 - val_accuracy: 0.6127
# Epoch 13/100
# 13/13 [==============================] - 3s 204ms/step - loss: 1.1637 - accuracy: 0.6894 - val_loss: 1.3327 - val_accuracy: 0.6408
# Epoch 14/100
# 13/13 [==============================] - 3s 204ms/step - loss: 1.0962 - accuracy: 0.7074 - val_loss: 1.3204 - val_accuracy: 0.6413
# Epoch 15/100
# 13/13 [==============================] - 3s 205ms/step - loss: 1.0771 - accuracy: 0.7140 - val_loss: 1.5075 - val_accuracy: 0.6524
# Epoch 16/100
# 13/13 [==============================] - 3s 205ms/step - loss: 1.0651 - accuracy: 0.7216 - val_loss: 1.2490 - val_accuracy: 0.6568
# Epoch 17/100
# 13/13 [==============================] - 3s 206ms/step - loss: 1.0105 - accuracy: 0.7279 - val_loss: 1.2562 - val_accuracy: 0.6577
# Epoch 18/100
# 13/13 [==============================] - 3s 202ms/step - loss: 1.0106 - accuracy: 0.7324 - val_loss: 1.1993 - val_accuracy: 0.6681
# Epoch 19/100
# 13/13 [==============================] - 3s 204ms/step - loss: 0.9678 - accuracy: 0.7368 - val_loss: 1.1982 - val_accuracy: 0.6603
# Epoch 20/100
# 13/13 [==============================] - 3s 201ms/step - loss: 0.9459 - accuracy: 0.7412 - val_loss: 1.1580 - val_accuracy: 0.6785
# Epoch 21/100
# 13/13 [==============================] - 3s 207ms/step - loss: 0.9213 - accuracy: 0.7452 - val_loss: 1.1837 - val_accuracy: 0.6644
# Epoch 22/100
# 13/13 [==============================] - 3s 208ms/step - loss: 0.8955 - accuracy: 0.7490 - val_loss: 1.1321 - val_accuracy: 0.6781
# Epoch 23/100
# 13/13 [==============================] - 3s 209ms/step - loss: 0.8783 - accuracy: 0.7529 - val_loss: 1.1061 - val_accuracy: 0.6853
# Epoch 24/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.9370 - accuracy: 0.7509 - val_loss: 1.0788 - val_accuracy: 0.6905
# Epoch 25/100
# 13/13 [==============================] - 3s 207ms/step - loss: 0.8283 - accuracy: 0.7632 - val_loss: 1.0616 - val_accuracy: 0.6948
# Epoch 26/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.8218 - accuracy: 0.7642 - val_loss: 1.0411 - val_accuracy: 0.7032
# Epoch 27/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.8076 - accuracy: 0.7671 - val_loss: 1.0496 - val_accuracy: 0.6955
# Epoch 28/100
# 13/13 [==============================] - 3s 213ms/step - loss: 0.7950 - accuracy: 0.7698 - val_loss: 1.0208 - val_accuracy: 0.7139
# Epoch 29/100
# Epoch 68/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.3119 - accuracy: 0.9079 - val_loss: 1.0164 - val_accuracy: 0.7411
# Epoch 69/100
# 13/13 [==============================] - 3s 202ms/step - loss: 0.2982 - accuracy: 0.9120 - val_loss: 1.0539 - val_accuracy: 0.7421
# Epoch 70/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.2944 - accuracy: 0.9136 - val_loss: 1.0324 - val_accuracy: 0.7452
# Epoch 71/100
# 13/13 [==============================] - 3s 214ms/step - loss: 0.2820 - accuracy: 0.9173 - val_loss: 1.0449 - val_accuracy: 0.7429
# Epoch 72/100
# 13/13 [==============================] - 3s 211ms/step - loss: 0.2718 - accuracy: 0.9192 - val_loss: 1.0568 - val_accuracy: 0.7427
# Epoch 73/100
# 13/13 [==============================] - 3s 204ms/step - loss: 0.2665 - accuracy: 0.9222 - val_loss: 1.0655 - val_accuracy: 0.7392
# Epoch 74/100
# 13/13 [==============================] - 3s 201ms/step - loss: 0.2559 - accuracy: 0.9261 - val_loss: 1.0837 - val_accuracy: 0.7384
# Epoch 75/100
# 13/13 [==============================] - 3s 201ms/step - loss: 0.2629 - accuracy: 0.9230 - val_loss: 1.0837 - val_accuracy: 0.7385
# Epoch 76/100
# 13/13 [==============================] - 3s 202ms/step - loss: 0.2384 - accuracy: 0.9306 - val_loss: 1.1102 - val_accuracy: 0.7355
# Epoch 77/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.2311 - accuracy: 0.9337 - val_loss: 1.1488 - val_accuracy: 0.7290
# Epoch 78/100
# 13/13 [==============================] - 3s 207ms/step - loss: 0.2276 - accuracy: 0.9340 - val_loss: 1.0960 - val_accuracy: 0.7411
# Epoch 79/100
# 13/13 [==============================] - 3s 204ms/step - loss: 0.2195 - accuracy: 0.9362 - val_loss: 1.0924 - val_accuracy: 0.7418
# Epoch 80/100
# 13/13 [==============================] - 3s 202ms/step - loss: 0.2216 - accuracy: 0.9340 - val_loss: 1.1252 - val_accuracy: 0.7390
# Epoch 81/100
# 13/13 [==============================] - 3s 207ms/step - loss: 0.2076 - accuracy: 0.9412 - val_loss: 1.1364 - val_accuracy: 0.7385
# Epoch 82/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.2009 - accuracy: 0.9428 - val_loss: 1.1252 - val_accuracy: 0.7398
# Epoch 83/100
# 13/13 [==============================] - 3s 218ms/step - loss: 0.1923 - accuracy: 0.9450 - val_loss: 1.1591 - val_accuracy: 0.7308
# Epoch 84/100
# 13/13 [==============================] - 3s 204ms/step - loss: 0.1877 - accuracy: 0.9463 - val_loss: 1.1461 - val_accuracy: 0.7435
# Epoch 85/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.1840 - accuracy: 0.9474 - val_loss: 1.1735 - val_accuracy: 0.7377
# Epoch 86/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.1746 - accuracy: 0.9510 - val_loss: 1.1752 - val_accuracy: 0.7397
# Epoch 87/100
# 13/13 [==============================] - 3s 203ms/step - loss: 0.1726 - accuracy: 0.9515 - val_loss: 1.1928 - val_accuracy: 0.7356
# Epoch 88/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.1618 - accuracy: 0.9544 - val_loss: 1.1951 - val_accuracy: 0.7432
# Epoch 89/100
# 13/13 [==============================] - 3s 213ms/step - loss: 0.1613 - accuracy: 0.9558 - val_loss: 1.2129 - val_accuracy: 0.7335
# Epoch 90/100
# 13/13 [==============================] - 3s 210ms/step - loss: 0.1578 - accuracy: 0.9546 - val_loss: 1.2149 - val_accuracy: 0.7376
# Epoch 91/100
# 13/13 [==============================] - 3s 210ms/step - loss: 0.1470 - accuracy: 0.9590 - val_loss: 1.2249 - val_accuracy: 0.7337
# Epoch 92/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.1483 - accuracy: 0.9576 - val_loss: 1.2327 - val_accuracy: 0.7324
# Epoch 93/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.1463 - accuracy: 0.9583 - val_loss: 1.2649 - val_accuracy: 0.7340
# Epoch 94/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.1339 - accuracy: 0.9620 - val_loss: 1.2807 - val_accuracy: 0.7327
# Epoch 95/100
# 13/13 [==============================] - 3s 202ms/step - loss: 0.1360 - accuracy: 0.9616 - val_loss: 1.2535 - val_accuracy: 0.7419
# Epoch 96/100
# 13/13 [==============================] - 3s 200ms/step - loss: 0.1253 - accuracy: 0.9647 - val_loss: 1.2591 - val_accuracy: 0.7405
# Epoch 97/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.1233 - accuracy: 0.9663 - val_loss: 1.2743 - val_accuracy: 0.7403
# Epoch 98/100
# 13/13 [==============================] - 3s 201ms/step - loss: 0.1246 - accuracy: 0.9642 - val_loss: 1.2936 - val_accuracy: 0.7368
# Epoch 99/100
# 13/13 [==============================] - 3s 208ms/step - loss: 0.1197 - accuracy: 0.9652 - val_loss: 1.2975 - val_accuracy: 0.7385
# Epoch 100/100
# 13/13 [==============================] - 3s 206ms/step - loss: 0.1146 - accuracy: 0.9671 - val_loss: 1.2891 - val_accuracy: 0.7392

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Vaya.
#
# -
# Input sentence: Go.
# Decoded sentence: Vaya.
#
# -
# Input sentence: Go.
# Decoded sentence: Vaya.
#
# -
# Input sentence: Go.
# Decoded sentence: Vaya.
#
# -
# Input sentence: Hi.
# Decoded sentence: Hola.
#
# -
# Input sentence: Run!
# Decoded sentence: ¡Corre!
#
# -
# Input sentence: Run.
# Decoded sentence: Corred.
#
# -
# Input sentence: Who?
# Decoded sentence: ¿Quién?
#
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# -
# Input sentence: Fire!
# Decoded sentence: ¡Disparad!
#
# -
# Input sentence: Help!
# Decoded sentence: ¡Socorro! ¡Auxilio!
#
# -
# Input sentence: Help!
# Decoded sentence: ¡Socorro! ¡Auxilio!
#
# -
# Input sentence: Help!
# Decoded sentence: ¡Socorro! ¡Auxilio!
#
# -
# Input sentence: Jump!
# Decoded sentence: ¡Salta!
#
# -
# Input sentence: Jump.
# Decoded sentence: Salte.
#
# -
# Input sentence: Stop!
# Decoded sentence: ¡Para!
#
# -
# Input sentence: Stop!
# Decoded sentence: ¡Para!
#
# -
# Input sentence: Stop!
# Decoded sentence: ¡Para!
#
# -
# Input sentence: Wait!
# Decoded sentence: ¡Espera!
#
# -
# Input sentence: Wait.
# Decoded sentence: Esperen.
#
# -
# Input sentence: Go on.
# Decoded sentence: Continú.
#
# -
# Input sentence: Go on.
# Decoded sentence: Continú.
#
# -
# Input sentence: Hello!
# Decoded sentence: ¡ola.
#
# -
# Input sentence: I ran.
# Decoded sentence: Corrí.
#
# -
# Input sentence: I ran.
# Decoded sentence: Corrí.
#
# -
# Input sentence: I try.
# Decoded sentence: Lo intento.
#
# -
# Input sentence: I won!
# Decoded sentence: ¡He ganado!
#
# -
# Input sentence: Oh no!
# Decoded sentence: ¡Oh, no!
#
# -
# Input sentence: Relax.
# Decoded sentence: Tomátelo con soda.
#
# -
# Input sentence: Smile.
# Decoded sentence: Sonríe.
#
# -
# Input sentence: Attack!
# Decoded sentence: ¡Al ataque!
#
# -
# Input sentence: Attack!
# Decoded sentence: ¡Al ataque!
#
# -
# Input sentence: Get up.
# Decoded sentence: Salte.
#
# -
# Input sentence: Go now.
# Decoded sentence: Ve paras.
#
# -
# Input sentence: Got it!
# Decoded sentence: ¡Lo tengo!
#
# -
# Input sentence: Got it?
# Decoded sentence: ¿Lo pillas?
#
# -
# Input sentence: Got it?
# Decoded sentence: ¿Lo pillas?
#
# -
# Input sentence: He ran.
# Decoded sentence: Él corrió.
#
# -
# Input sentence: Hop in.
# Decoded sentence: Métete adentro.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Abrázame.
#
# -
# Input sentence: I fell.
# Decoded sentence: Me caí.
#
# -
# Input sentence: I know.
# Decoded sentence: Yo lo sé.
#
# -
# Input sentence: I left.
# Decoded sentence: Me tenda.
#
# -
# Input sentence: I lied.
# Decoded sentence: Mentí.
#
# -
# Input sentence: I lost.
# Decoded sentence: De mí.
#
# -
# Input sentence: I quit.
# Decoded sentence: Renuncié.
#
# -
# Input sentence: I quit.
# Decoded sentence: Renuncié.
#
# -
# Input sentence: I work.
# Decoded sentence: Estoy trabajando.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: Tengo diecinueve.
#
# -
# Input sentence: I'm up.
# Decoded sentence: Soy yalo.
#
# -
# Input sentence: Listen.
# Decoded sentence: Escuche.
#
# -
# Input sentence: Listen.
# Decoded sentence: Escuche.
#
# -
# Input sentence: Listen.
# Decoded sentence: Escuche.
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: No way!
# Decoded sentence: ¡De ninguna manera!
#
# -
# Input sentence: Really?
# Decoded sentence: ¿La verdad?
#
# -
# Input sentence: Really?
# Decoded sentence: ¿La verdad?
#
# -
# Input sentence: Thanks.
# Decoded sentence: Gracias.
#
# -
# Input sentence: Thanks.
# Decoded sentence: Gracias.
#
# -
# Input sentence: Try it.
# Decoded sentence: Pruébalo.
#
# -
# Input sentence: We try.
# Decoded sentence: Lo procuramos.
#
# -
# Input sentence: We won.
# Decoded sentence: Ganamos.
#
# -
# Input sentence: Why me?
# Decoded sentence: ¿Por qué yo?
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Pregúntale a Tom.
#
# -
# Input sentence: Awesome!
# Decoded sentence: ¡Órale!
#
# -
# Input sentence: Be calm.
# Decoded sentence: Mantente en calma.
#
# -
# Input sentence: Be cool.
# Decoded sentence: Séntente.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Sé justo.
#
# -
# Input sentence: Be kind.
# Decoded sentence: Sean gentiles.
#
# -
# Input sentence: Be nice.
# Decoded sentence: Sé agradable.
#
# -
# Input sentence: Beat it.
# Decoded sentence: Salte.
#
# -
# Input sentence: Call me.
# Decoded sentence: Llamadme.
#
# -
# Input sentence: Call me.
# Decoded sentence: Llamadme.
#
# -
# Input sentence: Call me.
# Decoded sentence: Llamadme.
#
# -
# Input sentence: Call us.
# Decoded sentence: Llámanos.
#
# -
# Input sentence: Come in.
# Decoded sentence: ¡Entren!
#
# -
# Input sentence: Come in.
# Decoded sentence: ¡Entren!
#
# -
# Input sentence: Come in.
# Decoded sentence: ¡Entren!
#
# -
# Input sentence: Come on!
# Decoded sentence: ¡Órale!
#
# -
# Input sentence: Come on.
# Decoded sentence: ¡Órale!
#
# -
# Input sentence: Come on.
# Decoded sentence: ¡Órale!
#
# -
# Input sentence: Drop it!
# Decoded sentence: Suéltalo.
#
# -
# Input sentence: Get Tom.
# Decoded sentence: Salga a Tom.
#
# -
# Input sentence: Get out!
# Decoded sentence: ¡Sette!
#
# -
# Input sentence: Get out.
# Decoded sentence: Salte.
#
# -
# Input sentence: Get out.
# Decoded sentence: Salte.
#
# -
# Input sentence: Get out.
# Decoded sentence: Salte.
#
# -
# Input sentence: Get out.
# Decoded sentence: Salte.
#
# -
# Input sentence: Get out.
# Decoded sentence: Salte.
#
# -
# Input sentence: Go away!
# Decoded sentence: ¡Largo!
#
# -
# Input sentence: Go away!
# Decoded sentence: ¡Largo!
